# %% [markdown]
# # notebooks/setup.ipynb

# %%
# Jupyter-Notebook installieren
# !pip install notebook
# !jupyter notebook
# Out:
# ...
# [I 2025-04-26 13:41:42.383 ServerApp] jupyter_lsp | extension was successfully linked.
# [I 2025-04-26 13:41:42.388 ServerApp] jupyter_server_terminals | extension was successfully linked.
# [I 2025-04-26 13:41:42.394 ServerApp] jupyterlab | extension was successfully linked.
# [W 2025-04-26 13:41:42.397 JupyterNotebookApp] 'use_redirect_file' has moved from NotebookApp to ServerApp. This config will be passed to ServerApp. Be sure to update your config before our next release.
# [W 2025-04-26 13:41:42.397 JupyterNotebookApp] 'use_redirect_file' has moved from NotebookApp to ServerApp. This config will be passed to ServerApp. Be sure to update your config before our next release.
# [I 2025-04-26 13:41:42.399 ServerApp] notebook | extension was successfully linked.
# ...

# %%
# %pip install python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
